# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x = np.arange(0,math.pi*2,0.05)
x
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  , 1.05,
#        1.1 , 1.15, 1.2 , 1.25, 1.3 , 1.35, 1.4 , 1.45, 1.5 , 1.55, 1.6 ,
#        1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 , 1.95, 2.  , 2.05, 2.1 , 2.15,
#        2.2 , 2.25, 2.3 , 2.35, 2.4 , 2.45, 2.5 , 2.55, 2.6 , 2.65, 2.7 ,
#        2.75, 2.8 , 2.85, 2.9 , 2.95, 3.  , 3.05, 3.1 , 3.15, 3.2 , 3.25,
#        3.3 , 3.35, 3.4 , 3.45, 3.5 , 3.55, 3.6 , 3.65, 3.7 , 3.75, 3.8 ,
#        3.85, 3.9 , 3.95, 4.  , 4.05, 4.1 , 4.15, 4.2 , 4.25, 4.3 , 4.35,
#        4.4 , 4.45, 4.5 , 4.55, 4.6 , 4.65, 4.7 , 4.75, 4.8 , 4.85, 4.9 ,
#        4.95, 5.  , 5.05, 5.1 , 5.15, 5.2 , 5.25, 5.3 , 5.35, 5.4 , 5.45,
#        5.5 , 5.55, 5.6 , 5.65, 5.7 , 5.75, 5.8 , 5.85, 5.9 , 5.95, 6.  ,
#        6.05, 6.1 , 6.15, 6.2 , 6.25])

# %%
y=np.sin(x)
y
# Out:
# array([ 0.        ,  0.04997917,  0.09983342,  0.14943813,  0.19866933,
#         0.24740396,  0.29552021,  0.34289781,  0.38941834,  0.43496553,
#         0.47942554,  0.52268723,  0.56464247,  0.60518641,  0.64421769,
#         0.68163876,  0.71735609,  0.75128041,  0.78332691,  0.8134155 ,
#         0.84147098,  0.86742323,  0.89120736,  0.91276394,  0.93203909,
#         0.94898462,  0.96355819,  0.97572336,  0.98544973,  0.99271299,
#         0.99749499,  0.99978376,  0.9995736 ,  0.99686503,  0.99166481,
#         0.98398595,  0.97384763,  0.9612752 ,  0.94630009,  0.92895972,
#         0.90929743,  0.88736237,  0.86320937,  0.83689879,  0.8084964 ,
#         0.7780732 ,  0.74570521,  0.71147335,  0.67546318,  0.6377647 ,
#         0.59847214,  0.55768372,  0.51550137,  0.47203054,  0.42737988,
#         0.38166099,  0.33498815,  0.28747801,  0.23924933,  0.19042265,
#         0.14112001,  0.09146464,  0.04158066, -0.00840725, -0.05837414,
# ...

# %%
plt.plot(x,y)
plt.show()

# %%
plt.xlabel("angle")
plt.ylabel("sine")
plt.title("sine curve")
plt.plot(x,y)
plt.show()

# %%
from numpy import *
from pylab import *
x=linspace(-3,3,30)
x
y=x**2
y
plot(x,y)
show()

# %%
#ax.bar(x,height,width,bottom,align)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
langs=['C','C++','Java','Python','PHP']
students=[23,17,36,29,12]
ax.bar(langs,students)
plt.show()

# %%
data=[[30,25,50,20],
      [40,23,51,17],
      [35,22,45,19]]
print(data)
X=np.arange(4)
print(X)
fig= plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.bar(X+0.00,data[0],color='b',width=0.25)
ax.bar(X+0.25,data[1],color='g',width=0.25)
ax.bar(X+0.50,data[2],color='r',width=0.25)
plt.show()
# Out:
# [[30, 25, 50, 20], [40, 23, 51, 17], [35, 22, 45, 19]]
# [0 1 2 3]

# %%
N=5
menMeanscore=(20,35,30,35,27)
womenMeanscore=(25,32,34,20,25)
ind=np.arange(N)
width=0.35
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.bar(ind,menMeanscore,width,color='r')
ax.bar(ind,womenMeanscore,width,bottom=menMeanscore,color='b')
ax.set_xlabel('Gender')
ax.set_ylabel("Scores")
ax.set_title('Scores by group and gender')
ax.set_xticks(ind,('G1','G2','G3','G4','G5'))
ax.set_yticks(np.arange(0,81,10))
ax.legend(labels=['Men','Women'])
plt.show()

# %%
fig,ax=plt.subplots(1,1)
a=np.array([22,87,5,43,56,78,45,34,32,2,98,4,13,23,54])
ax.hist(a,bins=[0,25,50,75,100],color='c')
ax.set_title('histogram of result')
ax.set_xticks([0,25,50,75,100])
ax.set_xlabel('marks')
ax.set_ylabel('no. of students')
plt.show()

# %%
a=np.array([22,87,5,43,56,
            73,55,54,11,20,
            51,5,79,31,27])
print(a.shape)
fig,ax=plt.subplots(figsize=(10,7))
ax.hist(a,bins=[0,25,50,75,100],color='c')

plt.show()
# Out:
# (15,)

# %%
a=np.array([22,87,5,43,56,
            73,55,54,11,20,
            51,5,79,31,27])
ind=np.arange(0,100,35)
print(a.shape)
fig,ax=plt.subplots(figsize=(10,7))
ax.hist(a,bins=[0,25,50,75,100],color='c')
ax.set_xticks(np.arange(0,100,35),('Slowlearner','AverageLearner','AdvancedLearner'))
plt.show()
# Out:
# (15,)

# %% [markdown]
# #How random seed works?

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

#Creating a Dataset
np.random.seed(23685752)
N_points=10000
n_bins=20

#Creating the distribution
x=np.random.randn(N_points)
y=0.8**x+np.random.randn(10000)+25

#Creating the histogram
fig,axs=plt.subplots(1,1,figsize=(10,7),tight_layout=True)

axs.hist(x,bins=n_bins)

plt.show()
